# %% [markdown]
# <a href="https://colab.research.google.com/github/manueljm77/EDC_AnalisisDeDatos/blob/main/Limpieza_Bosch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXPLORACIÓN Y LIMPIEZA DEL DATASET
#
# [Dataset](https://www.kaggle.com/datasets/teajay/global-shark-attacks?select=attacks.csv)

# %% [markdown]
# - Cargamos **librerías, funciones y el data set** que vamos a usar para la limpieza

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.simplefilter("ignore")

# %%
ds = pd.read_csv("https://gist.githubusercontent.com/javierIA/f404c5b368e878da515028074882998d/raw/74faa7572c5b4a61214d3bfc92334da74c5d637b/attacks.csv",encoding = "ISO-8859-1")

# %% [markdown]
# - Hacemos una copia del data set "just in case"...

# %%
df = ds.copy()

# %% [markdown]
# # EXPLORACIÓN DATA SET

# %% [markdown]
# ![alt text](https://pbs.twimg.com/media/E7RUoEvWUAAL2aH.jpg "")

# %%
df.shape #25.723 Lineas y 24 columnas
# Out:
# (25723, 24)

# %%
df.sample(10)
# Out:
#       Case Number         Date    Year        Type      Country      Area  \
# 12942         NaN          NaN     NaN         NaN          NaN       NaN
# 21400         NaN          NaN     NaN         NaN          NaN       NaN
# 10382         NaN          NaN     NaN         NaN          NaN       NaN
# 14284         NaN          NaN     NaN         NaN          NaN       NaN
# 11615         NaN          NaN     NaN         NaN          NaN       NaN
# 20898         NaN          NaN     NaN         NaN          NaN       NaN
# 4104   1959.03.08  08-Mar-1959  1959.0  Unprovoked  PHILIPPINES  Mindanao
# 8455            0          NaN     NaN         NaN          NaN       NaN
# 22938         NaN          NaN     NaN         NaN          NaN       NaN
# 6849            0          NaN     NaN         NaN          NaN       NaN
#
#                                   Location           Activity  \
# 12942                                  NaN                NaN
# 21400                                  NaN                NaN
# 10382                                  NaN                NaN
# 14284                                  NaN                NaN
# 11615                                  NaN                NaN
# 20898                                  NaN                NaN
# 4104   Mouth of Langoyan River, Davao City  Lifeboat capsized
# 8455                                   NaN                NaN
# 22938                                  NaN                NaN
# 6849                                   NaN                NaN
#
#                                                     Name Sex   ... Species   \
# 12942                                                NaN  NaN  ...      NaN
# 21400                                                NaN  NaN  ...      NaN
# 10382                                                NaN  NaN  ...      NaN
# 14284                                                NaN  NaN  ...      NaN
# 11615                                                NaN  NaN  ...      NaN
# 20898                                                NaN  NaN  ...      NaN
# 4104   Leopoldo Sanchez, a messboy from the ship MV M...    M  ...      NaN
# 8455                                                 NaN  NaN  ...      NaN
# 22938                                                NaN  NaN  ...      NaN
# 6849                                                 NaN  NaN  ...      NaN
#
#                                   Investigator or Source  \
# 12942                                                NaN
# 21400                                                NaN
# 10382                                                NaN
# 14284                                                NaN
# 11615                                                NaN
# 20898                                                NaN
# 4104   Manila Chronicle, 3/10/1959; P. Gilbert, L. Sc...
# 8455                                                 NaN
# 22938                                                NaN
# 6849                                                 NaN
#
#                           pdf  \
# 12942                     NaN
# 21400                     NaN
# 10382                     NaN
# 14284                     NaN
# 11615                     NaN
# 20898                     NaN
# 4104   1959.03.08-Sanchez.pdf
# 8455                      NaN
# 22938                     NaN
# 6849                      NaN
#
#                                             href formula  \
# 12942                                                NaN
# 21400                                                NaN
# 10382                                                NaN
# 14284                                                NaN
# 11615                                                NaN
# 20898                                                NaN
# 4104   http://sharkattackfile.net/spreadsheets/pdf_di...
# 8455                                                 NaN
# 22938                                                NaN
# 6849                                                 NaN
#
#                                                     href Case Number.1  \
# 12942                                                NaN           NaN
# 21400                                                NaN           NaN
# 10382                                                NaN           NaN
# 14284                                                NaN           NaN
# 11615                                                NaN           NaN
# 20898                                                NaN           NaN
# 4104   http://sharkattackfile.net/spreadsheets/pdf_di...    1959.03.08
# 8455                                                 NaN           NaN
# 22938                                                NaN           NaN
# 6849                                                 NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 12942           NaN            NaN         NaN         NaN
# 21400           NaN            NaN         NaN         NaN
# 10382           NaN            NaN         NaN         NaN
# 14284           NaN            NaN         NaN         NaN
# 11615           NaN            NaN         NaN         NaN
# 20898           NaN            NaN         NaN         NaN
# 4104     1959.03.08         2199.0         NaN         NaN
# 8455            NaN            NaN         NaN         NaN
# 22938           NaN            NaN         NaN         NaN
# 6849            NaN            NaN         NaN         NaN
#
# [10 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
df.describe().T #Solo hay dos columnas creadas como numéricas
# Out:
#                  count         mean          std  min     25%     50%     75%  \
# Year            6300.0  1927.272381   281.116308  0.0  1942.0  1977.0  2005.0
# original order  6309.0  3155.999683  1821.396206  2.0  1579.0  3156.0  4733.0
#
#                    max
# Year            2018.0
# original order  6310.0

# %%
#print(df.isna())
#print(df.isna().sum())
#print(df.isna().sum()*100/len(df))
#print(round(df.isna().sum()*100/len(df),2))
Nan_percentage = round(df.isna().sum()*100/len(df),2) #Calculo el porcentaje de valores NaN
Nan_percentage.sort_values(ascending = False)
# Out:
# Unnamed: 22               100.00
# Unnamed: 23                99.99
# Time                       88.54
# Species                    86.53
# Age                        86.51
# Sex                        77.70
# Activity                   77.62
# Fatal (Y/N)                77.60
# Location                   77.60
# Area                       77.27
# Name                       76.32
# Country                    75.69
# Injury                     75.61
# Investigator or Source     75.57
# Type                       75.52
# Year                       75.51
# Date                       75.50
# pdf                        75.50
# href formula               75.50
# href                       75.50
# Case Number.1              75.50
# Case Number.2              75.50
# original order             75.47
# Case Number                66.17
# dtype: float64

# %% [markdown]
# ![alt text](https://opendatascience.com/wp-content/uploads/2021/04/Monkey-Escape-Room-Meme.jpg "Cleaning data")

# %% [markdown]
# - Muchas columnas tienen demasiado porcentaje de NaN's por lo que podremos prescindir de ellas ya que no aportan información.
# - Vamos a eliminar todas las filas que tienen NaN en todos sus campos

# %%
df.dropna(axis=0, inplace= True, how='all') #Elimino las filas que tienen todos los valores NaN

# %%
df.shape #Ahora tenemos 8.703 filas
# Out:
# (8703, 24)

# %% [markdown]
# - Hay muchas filas que tienen un porcentaje demasiado alto de NaN, por lo que vamos a eliminar también las filas que tienen un 80% de NaN en su contenido

# %%
df.dropna(axis=0, inplace= True, thresh=int(24*0.8))

# %% [markdown]
# - Actualizamos el porcentaje de NaN's de cada columna:

# %%
valores_nulos = df.isnull().sum()
porcentajes_nulos = valores_nulos / df.shape[0] * 100
porcentajes_nulos_ordenados = porcentajes_nulos.sort_values(ascending=False)
porcentajes_nulos_ordenados
# Out:
# Unnamed: 22               99.981252
# Unnamed: 23               99.962505
# Time                      45.406824
# Species                   40.101237
# Age                       36.164229
# Fatal (Y/N)                6.786652
# Sex                        4.068241
# Activity                   2.868391
# Location                   2.699663
# Area                       1.931009
# Name                       0.449944
# Investigator or Source     0.093738
# Country                    0.037495
# Injury                     0.037495
# Type                       0.018748
# href formula               0.018748
# Date                       0.000000
# pdf                        0.000000
# href                       0.000000
# Case Number.1              0.000000
# Case Number.2              0.000000
# original order             0.000000
# Year                       0.000000
# Case Number                0.000000
# dtype: float64

# %% [markdown]
# - Vamos a ver si hay alguna fila duplicada, en tal caso las eliminaremos

# %%
df.duplicated().sum()
# Out:
# 0

# %%
duplicadas = df[df.duplicated()]
duplicadas
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6310            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6311            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6312            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6313            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6314            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 6310   ...      NaN                    NaN  NaN          NaN  NaN
# 6311   ...      NaN                    NaN  NaN          NaN  NaN
# 6312   ...      NaN                    NaN  NaN          NaN  NaN
# 6313   ...      NaN                    NaN  NaN          NaN  NaN
# 6314   ...      NaN                    NaN  NaN          NaN  NaN
# ...    ...      ...                    ...  ...          ...  ...
# 25717  ...      NaN                    NaN  NaN          NaN  NaN
# 25718  ...      NaN                    NaN  NaN          NaN  NaN
# 25719  ...      NaN                    NaN  NaN          NaN  NaN
# 25720  ...      NaN                    NaN  NaN          NaN  NaN
# 25721  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 6310            NaN           NaN            NaN         NaN         NaN
# 6311            NaN           NaN            NaN         NaN         NaN
# 6312            NaN           NaN            NaN         NaN         NaN
# 6313            NaN           NaN            NaN         NaN         NaN
# 6314            NaN           NaN            NaN         NaN         NaN
# ...             ...           ...            ...         ...         ...
# 25717           NaN           NaN            NaN         NaN         NaN
# 25718           NaN           NaN            NaN         NaN         NaN
# 25719           NaN           NaN            NaN         NaN         NaN
# 25720           NaN           NaN            NaN         NaN         NaN
# 25721           NaN           NaN            NaN         NaN         NaN
#
# [19411 rows x 24 columns]

# %%
df.drop_duplicates(inplace=True) #Elimino las filas duplicadas
df.reset_index(drop=True, inplace=True) #Reiniciamos el índice

# %% [markdown]
# - Eliminamos las columnas 'Unnamed: 22' y 'Unnamed: 23', ya vimos antes que eran prácticamente 100% NaN

# %%
df.drop(['Unnamed: 22','Unnamed: 23'], axis=1, inplace=True)

# %% [markdown]
# - Veámos como están escritos los nombres de las columnas

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %% [markdown]
# - Quitemos los espacios en blanco en los nombres de las columnas, capitalicemos los nombres y sustituyamos espacios por guiones bajos

# %%
df.columns = df.columns.str.strip().str.capitalize().str.replace(' ', '_')

# %% [markdown]
# # LIMPIEZA

# %% [markdown]
# ![alt text](https://media.makeameme.org/created/data-cleanup-is.jpg "Dropna")

# %% [markdown]
# - Quitamos todas las filas y columnas que tengan todo NaN

# %%
df.columns
# Out:
# Index(['Case_number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal_(y/n)', 'Time',
#        'Species', 'Investigator_or_source', 'Pdf', 'Href_formula', 'Href',
#        'Case_number.1', 'Case_number.2', 'Original_order'],
#       dtype='object')

# %% [markdown]
# - Echando una ojeada a estas columnas podemos descartarlas ya que no nos van a aportar al estudio que vamos a hacer

# %%
print(df["Href"][3513],df['Href_formula'][3513])
# Out:
# http://sharkattackfile.net/spreadsheets/pdf_directory/1962.01.01-Caberto.pdf http://sharkattackfile.net/spreadsheets/pdf_directory/1962.01.01-Caberto.pdf

# %% [markdown]
# - Contienen vínculos a archivos pdf donde vienen registrados datos del ataque en pdf: imagenes, recortes de periódico, fotos de la ubicación, etc...
#
# https://sharkattackfile.net/spreadsheets/pdf_directory/1967.08.25-Casucci.pdf

# %% [markdown]
# - Ojeadas las columnas podemos hacer **drop** de las que **no considero interesantes** para el caso:
#
# ``'Case_number','Investigator_or_source', 'Pdf', 'Href_formula', 'Href', 'Case_number.1', 'Case_number.2', 'Original_order'``

# %%
df.drop(['Case_number','Investigator_or_source', 'Pdf', 'Href_formula', 'Href', 'Case_number.1', 'Case_number.2', 'Original_order'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal_(y/n)', 'Time', 'Species'],
#       dtype='object')

# %% [markdown]
# ### YEAR Y DATE COLUMN

# %%
df.Year.unique() #Vamos a ver si podemos rescatar algun año a través del contenido de la columna date
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994., 1993.,
#        1992., 1991., 1990., 1989., 1988., 1987., 1986., 1985., 1983.,
#        1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975., 1974.,
#        1973., 1972., 1971., 1970., 1969., 1968., 1967., 1966., 1965.,
#        1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#        1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1848.,
#        1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939.,
#        1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931., 1930.,
#        1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922., 1921.,
#        1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913., 1912.,
#        1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904., 1903.,
#        1902., 1901., 1900., 1899., 1898., 1897., 1896., 1895., 1894.,
#        1893., 1892., 1891., 1890., 1889., 1888., 1887., 1886., 1885.,
#        1884., 1883., 1882., 1881., 1880., 1879., 1878., 1877., 1876.,
#        1875., 1874., 1873., 1872., 1871., 1870., 1869., 1868., 1867.,
#        1866., 1865., 1864., 1863., 1862., 1861., 1860., 1859., 1858.,
#        1857., 1856., 1855., 1853., 1852., 1851., 1849., 1847., 1846.,
#        1845., 1842., 1841., 1840., 1839., 1837., 1835., 1834., 1832.,
#        1831., 1830., 1829., 1828., 1827., 1825., 1817., 1816., 1812.,
#        1810., 1780., 1779., 1749., 1748., 1738., 1721., 1703., 1700.,
#        1642., 1595.,    0.])

# %% [markdown]
# - Vemos años un poco raros, así que paso a verlos en detalle

# %%
#pd.set_option('max_rows', None)

# %%
df[['Date','Year']][df.Year == 0] #81 fechas que podemos rescatar a través de date
# Out:
#                     Date  Year
# 5253       Ca. 336.B.C..   0.0
# 5254        Ca. 725 B.C.   0.0
# 5255        1990 or 1991   0.0
# 5256         Before 2016   0.0
# 5257     Before Oct-2009   0.0
# ...                  ...   ...
# 5329  Before 19-Jul-1913   0.0
# 5330         Before 1906   0.0
# 5331         Before 1903   0.0
# 5332           1900-1905   0.0
# 5333           1845-1853   0.0
#
# [81 rows x 2 columns]

# %% [markdown]
# Hay 81 lineas con el df.Year == CERO pero en df.Date si que figuran datos, a ver que podemos rescatar de ahí.
# Muchos corresponend con intervalos de años, otros indica before 'alguna fecha' y en otro habla sobre la guerra, suponemos que la Segunda Guerra Mundial

# %%
df.Date = df.Date.replace(regex=r'(?i)Reported\s{1,9}',value='')
list(df.Date.unique())
# Out:
# ['25-Jun-2018',
#  '18-Jun-2018',
#  '09-Jun-2018',
#  '08-Jun-2018',
#  '04-Jun-2018',
#  '03-Jun-2018',
#  '13-Dec-2015',
#  '11-Dec-2015',
#  '08-Dec-2015',
#  '20-Nov-2015',
#  '16-Nov-2015',
#  '15-Nov-2015',
#  '10-Nov-2015',
#  '07-Nov-2015',
#  '03-Nov-2015',
#  '01-Nov-2015',
#  '30-Oct-2015',
#  '28-Oct-2015',
#  '25-Oct-2015',
#  '21-Oct-2015',
#  '19-Oct-2015',
#  '17-Oct-2015',
#  '13-Oct-2015',
#  '09-Oct-2015',
#  '08-Oct-2015',
#  '07-Oct-2015',
#  '05-Oct-2015',
#  '04-Oct-2015',
#  '29-Sep-2015',
#  '26-Sep-2015',
#  '24-Sep-2015',
#  '20-Sep-2015',
#  '19-Sep-2015',
#  '18-Sep-2015',
#  '17-Sep-2015',
#  '08-Sep-2015',
#  '06-Sep-2015',
#  '05-Sep-2015',
#  '04-Sep-2015',
#  '03-Sep-2015',
#  '01-Sep-2015',
#  '29-Aug-2015',
#  '22-Aug-2015',
#  '20-Aug-2015',
#  '19-Aug-2015',
#  '18-Aug-2015',
#  '10-Aug-2015',
#  '31-Jul-2015',
#  '28-Jul-2015',
#  '26-Jul-2015',
#  '25-Jul-2015',
#  '23-Jul-2015',
#  '22-Jul-2015',
#  '19-Jul-2015',
#  '10-Jul-2015',
#  '08-Jul-2015',
#  '04-Jul-2015',
#  '03-Jul-2015',
#  '02-Jul-2015',
#  '01-Jul-2015',
#  '30-Jun-2015',
#  '27-Jun-2015',
#  '26-Jun-2015',
#  '25-Jun-2015',
#  '24-Jun-2015',
#  '23-Jun-2015',
#  '19-Jun-2015',
#  '17-Jun-2015',
#  '14-Jun-2015',
#  '13-Jun-2015',
#  '11-Jun-2015',
#  '07-Jun-2015',
#  '05-Jun-2015',
#  '01-Jun-2015',
#  '29-May-2015',
#  '25-May-2015',
#  '24-May-2015',
#  '20-May2015',
#  '15-May-2015',
#  '09-May-2015',
#  '07-May-2015',
#  '03-May-2015',
#  '02-May-2015',
#  '29-Apr-2015',
#  '26-Apr-2015',
#  '25-Apr-2015',
#  '13-Apr-2015',
#  '12-Apr-2015',
#  '11-Apr-2015',
#  '03-Apr-2015',
#  '29-Mar-2015',
#  '31-Mar-2015',
#  '26-Mar-2015',
#  '21-Mar-2015',
#  '18-Mar-2015',
#  '16-Mar-2015',
#  '11-Mar-2015',
#  '10-Mar-2015',
#  '07-Mar-2015',
#  '14-Feb-2015',
#  '09-Feb-2015',
#  '08-Feb-2015',
#  '05-Feb-2015',
#  '30-Jan-2015',
#  '27-Jan-2015',
#  '24-Jan-2015',
#  '23-Jan-2015',
#  '19-Jan-2015',
#  '17-Jan-2015',
#  '16-Jan-2015',
#  '08-Jan-2015',
#  '06-Jan-2015',
#  '03-Jan-2015',
#  '01-Jan-2015',
#  '29-Dec-2014',
#  '28-Dec-2014',
#  '15-Dec-2014',
#  '03-Dec-2014',
#  '29-Nov-2014',
#  '20-Nov-2014',
#  '19-Nov-2014',
#  '16-Nov-2014',
#  '13-Nov-2014',
#  '10-Nov-2014',
#  '08-Nov-2014',
#  '31-Oct-2014',
#  '29-Oct-2014',
#  '20-Jun-2008',
#  '11-Jun-2008',
#  '07-Jun-2008',
#  '02-Jun-2008',
#  '01-Jun-2008',
#  '26-May-2008',
#  '24-May-2008',
#  '23-May-2008',
#  '14-May-2008',
#  '10-May-2008',
#  '07-May-2008',
#  '28-Apr-2008',
#  '27-Apr-2008',
#  '26-Apr-2008',
#  '25-Apr-2008',
#  '20-Apr-2008',
#  '19-Apr-2008',
#  '18-Apr-2008',
#  '17-Apr-2008',
#  '15-Apr-2008',
#  '25-Mar-2008',
#  '08-Apr-2008',
#  '03-Apr-2008',
#  '28-Mar-2008',
#  '23-Mar-2008',
#  '21-Mar-2008',
#  '15-Mar-2008',
#  '07-Mar-2008',
#  '24-Feb-2008',
#  '21-Feb-2008',
#  '15-Feb-2008',
#  '07-Feb-2008',
#  ...]

# %% [markdown]
# - Aunque no salen en los **uniques** hay muchos Dates que salen como rangos, o datos de antes de Cristo.
# - Vamos a denominarlos momentáneamente salvables para ver cuantos hay exactamente:

# %%
salvables = df.loc[(df["Year"] == 0) & (df["Date"] != np.nan)]
salvables.shape
# Out:
# (81, 14)

# %%
df.describe()
# Out:
#               Year
# count  5334.000000
# mean   1943.141545
# std     244.938571
# min       0.000000
# 25%    1951.250000
# 50%    1985.000000
# 75%    2007.000000
# max    2018.000000

# %% [markdown]
# - Llamamos a las funciones definidas en el **cleanin_functions.py**, mas concretamente a rescatar fechas que aplica 3 funciones secuencialmente donde coge por orden los que contienen BC, los que son fechas sueltas (tipo Before YYYY) y luego los intervalos de los cuales saca la media, para rellenar los datos de df.Year para esos valores de df.Dates  #TODO, mira tema de late´s y demas para meterlos tb

# %%
import re
def BC(string):
    """Reemplaza las ocurrencias de 'B.C.' o 'bc' por NaN"""
    return np.nan if re.search(r'(?i)B\.?C', str(string)) else string

def rescatar_fechas(string):
    """Limpia y rescata las fechas de la cadena de texto"""
    string = BC(string)
    match = re.search(r'\d{4}', str(string))
    return match.group() if match else np.nan

# %%
df['Year'] = df.Date.apply(rescatar_fechas)

# %% [markdown]
# - Si miramos el dato primero de nuestra lista anterior vemos que:

# %%
df["Date"]
# Out:
# 0              25-Jun-2018
# 1              18-Jun-2018
# 2              09-Jun-2018
# 3              08-Jun-2018
# 4              04-Jun-2018
#                ...
# 5329    Before 19-Jul-1913
# 5330           Before 1906
# 5331           Before 1903
# 5332             1900-1905
# 5333             1845-1853
# Name: Date, Length: 5334, dtype: object

# %%
#pd.set_option('max_rows', None)

# %%
df[["Date","Year"]].sample(10)
# Out:
#               Date  Year
# 2029   13-Jan-1999  1999
# 1260   27-Sep-2007  2007
# 4482   16-Dec-1929  1929
# 561    10-Dec-2013  2013
# 490    10-Aug-2014  2014
# 3325   16-Jan-1965  1965
# 1274   28-Aug-2007  2007
# 4513   04-Nov-1928  1928
# 4239          1941  1941
# 2494   02-Nov-1989  1989

# %%
#pd.set_option('max_rows', 20)

# %% [markdown]
# ## AREA / LOCATION COLUMNS

# %% [markdown]
# - Ambas columnas son bastante imprecisas en cuanto a ubicacion, por lo que mejor voy a trabajar sobre la columna **country.**

# %%
paises = pd.read_csv("https://gist.githubusercontent.com/javierIA/c081bc9680af6763d8b515fb659c852c/raw/c3da588b6663b607fc87c31bfa2ffb19cc19cb37/paises.csv",encoding='utf-8')

lista_paises = paises["name"].tolist()

# %%
def paises (string):
    """"La funcion recorre la lista de países importada y va comparando conteido de la columna Country
    con el de países que se encuentra en data"""
    if string!=string:
        return np.nan
    string = str(string).lower().title().strip()
    if string!=string:
        return np.nan
    if "Usa" == string:
        string = "United States of America"
    if string == "England":
        string = "United Kingdom"
    if string == "Columbia":
        string = "Colombia"
    if string == "Scotland":
        string = "United Kingdom"
    if string == "Okinawa":
        string = "Japan"
    if string not in lista_paises:
        return np.nan
    else:
        return string

# %%
df[["Country","Area","Location"]].sample(50)
# Out:
#                  Country                                 Area  \
# 734            AUSTRALIA                    Western Australia
# 583                  USA                              Florida
# 4702                 USA                            Louisiana
# 5183                 USA                             Virginia
# 3645         NEW ZEALAND                         North Island
# 529                  USA                              Georgia
# 1308                 USA                       South Carolina
# 3246           AUSTRALIA                           Queensland
# 1939                 USA                              Florida
# 1960         NEW ZEALAND                         North Island
# 3630                 USA                           California
# 2532                 USA                           California
# 629                  USA                       South Carolina
# 4123                 USA                              Florida
# 1099           AUSTRALIA                      New South Wales
# 4088          NEW GUINEA  Abau Sub District, Central Province
# 1183        SOUTH AFRICA                Western Cape Province
# 4489                 USA                       South Carolina
# 1235             ECUADOR                    Galapagos Islands
# 4113           AUSTRALIA                      New South Wales
# 4780           AUSTRALIA                      New South Wales
# 4972  BRITISH NEW GUINEA                     Woodlark Islands
# 5141              GUINEA                       Conakry Region
# 325           MOZAMBIQUE                   Inhambane Province
# 4001           AUSTRALIA                      New South Wales
# 3722           AUSTRALIA                        Torres Strait
# 3971                 USA                              Florida
# 4701             JAMAICA                      Kingston Parish
# 2223                 USA                       South Carolina
# 2008        SOUTH AFRICA                Eastern Cape Province
# 4403           AUSTRALIA                           Queensland
# 4435                 USA                               Hawaii
# 5201           AUSTRALIA                           Queensland
# 669          NEW ZEALAND                      Mercury Islands
# 499              REUNION                            Saint-Leu
# 576            AUSTRALIA                      New South Wales
# 1244           AUSTRALIA                      New South Wales
# 2472             BAHAMAS                                  NaN
# 4968              CANADA                          Nova Scotia
# 1979                 USA                           California
# 2592           AUSTRALIA                      South Australia
# 3613                 USA                             Delaware
# 1781                 USA                              Florida
# 3683    PAPUA NEW GUINEA                          New Britain
# 5234        SIERRA LEONE                        Western Area
# 4850               ITALY                             Calabria
# 4603                 USA                           New Jersey
# 4254           AUSTRALIA                           Queensland
# 3012           HONG KONG                            Mirs Bay
# 233                  USA                       South Carolina
#
#                                                Location
# 734                               Mullaloo Beach, Perth
# 583                             Destin, Okaloosa County
# 4702                                 Lake Pontchartrain
# 5183                                            Norfolk
# 3645                          Mangawhai, near Wellsford
# 529                        Tybee Island, Chatham County
# 1308                                        Garden City
# 3246  Broomfield Island, 11 miles from Heron Island ...
# 1939  Smyrna Dunes Park, New Smyrna Beach, Volusia C...
# 1960       Between the Kakanui River and Campbell's Bay
# 3630                        Tomales Point, Marin County
# 2532  Latigo Point / Paradise Cove, west of Malibu, ...
# 629                          Myrtle Beach, Horry County
# 4123          In a canal 10 miles north of St Augustine
# 1099                  Shelly Beach, near Port Macquarie
# 4088                                           Kerpuna
# 1183                                         Struis Bay
# 4489                                      Fort Moultrie
# 1235                               San Cristobal Island
# 4113  Watson Taylor's Lake, 25 miles south of Port M...
# 4780    Middle Harbour, Sugarloaf Bay, Sydney (Estuary)
# 4972                                       Off Panamota
# 5141                                        Ile de Loss
# 325                             Nahaduga, Inhambane Bay
# 4001                                        North Bondi
# 3722  Coconut Island , 100 miles east of Thursday Is...
# 3971                      Juno Beach, Palm Beach County
# 4701                                         Port Royal
# 2223  Ocean Lakes Campground, south of Myrtle Beach,...
# 2008                           Cintsa East, East London
# 4403                               Off Bloomfield River
# 4435               1 mile off Mala Wharf, Lahaina, Maui
# 5201                                        Moreton Bay
# 669                                Great Mercury Island
# 499                                                 NaN
# 576                               South Narrabeen Beach
# 1244                            Wategos Beach, Byon Bay
# 2472                                             Bimini
# 4968                                            Halifax
# 1979                    Waddell Reef, Santa Cruz County
# 2592                             Merino Rocks, Adelaide
# 3613                     Mispillion Light, Delaware Bay
# 1781              Lauderdale-By-The-Sea, Broward County
# 3683                             Rapindik Beach, Rabaul
# 5234             Tombo Island in the Sierra Leone River
# 4850                                           Nicotera
# 4603                              Ocean City (offshore)
# 4254                                     Brisbane River
# 3012                                                NaN
# 233                    North Myrtle Beach, Horry County

# %%
df.Country = df.Country.apply(paises)
df.dropna(subset=["Country"], inplace=True)

# %%
df.Country.notna().sum()
# Out:
# 5186

# %%
df
# Out:
#                                                    Date  Year        Type  \
# 0                                           25-Jun-2018  2018     Boating
# 1                                           18-Jun-2018  2018  Unprovoked
# 2                                           09-Jun-2018  2018     Invalid
# 3                                           08-Jun-2018  2018  Unprovoked
# 4                                           04-Jun-2018  2018    Provoked
# ...                                                 ...   ...         ...
# 5328  No date (3 days after preceding incident) & pr...  1913  Unprovoked
# 5329                                 Before 19-Jul-1913  1913  Unprovoked
# 5330                                        Before 1906  1906  Unprovoked
# 5331                                        Before 1903  1903  Unprovoked
# 5332                                          1900-1905  1900  Unprovoked
#
#                        Country               Area  \
# 0     United States of America         California
# 1     United States of America            Georgia
# 2     United States of America             Hawaii
# 3                    Australia    New South Wales
# 4                       Mexico             Colima
# ...                        ...                ...
# 5328              South Africa      KwaZulu-Natal
# 5329              South Africa      KwaZulu-Natal
# 5330                 Australia    New South Wales
# 5331                 Australia  Western Australia
# 5332  United States of America     North Carolina
#
#                             Location     Activity                   Name Sex  \
# 0        Oceanside, San Diego County     Paddling            Julie Wolfe   F
# 1     St. Simon Island, Glynn County     Standing        Adyson McNeely    F
# 2                       Habush, Oahu      Surfing            John Denges   M
# 3                 Arrawarra Headland      Surfing                   male   M
# 4                           La Ticla  Free diving         Gustavo Ramos    M
# ...                              ...          ...                    ...  ..
# 5328                          Durban      Fishing     a native fisherman   M
# 5329                          Durban       Wading       a young Scotsman   M
# 5330                                     Swimming               Arab boy   M
# 5331                     Roebuck Bay       Diving                   male   M
# 5332                  Ocracoke Inlet     Swimming  Coast Guard personnel   M
#
#       Age                                             Injury Fatal_(y/n)  \
# 0      57  No injury to occupant, outrigger canoe and pad...           N
# 1      11                         Minor injury to left thigh           N
# 2      48       Injury to left lower leg from surfboard skeg           N
# 3     NaN                          Minor injury to lower leg           N
# 4     NaN  Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...   ...                                                ...         ...
# 5328  NaN  FATAL, body not recovered but shark was caught...           Y
# 5329  NaN                     FATAL, leg stripped of flesh             Y
# 5330  NaN                                              FATAL           Y
# 5331  NaN                                              FATAL           Y
# 5332  NaN                                              FATAL           Y
#
#                Time                                            Species
# 0             18h00                                        White shark
# 1     14h00  -15h00                                                NaN
# 2             07h45                                                NaN
# 3               NaN                                          2 m shark
# 4               NaN                                    Tiger shark, 3m
# ...             ...                                                ...
# 5328            NaN                                                NaN
# 5329            NaN                                                NaN
# 5330            NaN  Said to involve a grey nurse shark that leapt ...
# 5331            NaN                                                NaN
# 5332            NaN                                                NaN
#
# [5186 rows x 14 columns]

# %% [markdown]
# # ACTIVITY COLUMN

# %%
df.Activity.sample(30)
# Out:
# 3955                                             Standing
# 2287                                              Surfing
# 4473                                                  NaN
# 569                                         Shark fishing
# 4831    Ship's boat capsized in squall, captain & 2 sa...
# 3495                                             Swimming
# 2640                                              Surfing
# 2655                                        Body boarding
# 4333                                 Fishing for bluefish
# 3590                     Fell overboard, prop slashed arm
# 1863                                              Surfing
# 4996                                               Rowing
# 1637                                          Surf skiing
# 2213                                              Surfing
# 1686                                              Surfing
# 3806                                   Diving for trochus
# 363                                               Surfing
# 656                                          Spearfishing
# 1617                                      Boogie boarding
# 318                                                Wading
# 280                                               Surfing
# 3985                                              Fishing
# 2563                                             Swimming
# 5095                                              Fishing
# 2018                       Spearfishing & diving for paua
# 2892                                              Surfing
# 2511                                         Spearfishing
# 1050                                              Surfing
# 3045                            Free diving, Spearfishing
# 1299                                              Surfing
# Name: Activity, dtype: object

# %%
def actividad(string):
    """Con esto corregimos los datos erroneos en actividades y los agrupamos en actividades que nos interesen, swimming, diving,
    fishing, standing"""
    string = str(string).lower().strip()
    if string != string:
        return np.nan
    elif "swimming" in string or"bathing" in string or "floating" in string or "splashing" in string or "jumped into the water" in string or "playing" in string:
        return "swimming"
    elif "diving" in string or "snorkel" in string:
        return "diving"
    elif "fishing" in string:
        return "fishing"
    elif "surf" in string or "body boarding" in string or "body-boarding" in string or "boogie boarding" in string or "paddleskiing" in string:
        return "surf"
    elif "standing" in string:
        return "standing"
    elif "kayaking" in string or "ship" in string or "sail" in string or "boat" in string or "canoeing" in string or "board" in string or "rowing" in string or "fell into the water" in string:
        return "boating"
    elif "disaster" in string:
        return "sea disaster"
    elif "wading" in string or "walking" in string or "treading water" in string:
        return "walking"
    else:
        return np.nan

# %% [markdown]
# - La lista de actividades es amplia, vamos a agruparlas y filtrarlas a través de una función llamada actividad tambien contenida en cleaning_functions.py

# %%
df.Activity = df.Activity.apply(actividad)
df.Activity.sample(30)
# Out:
# 2026            surf
# 2686        swimming
# 2004        swimming
# 3528             NaN
# 323             surf
# 4737         boating
# 1374            surf
# 51              surf
# 4469        swimming
# 5242         boating
# 409          walking
# 1562          diving
# 4191         boating
# 2468         fishing
# 2086            surf
# 3646         fishing
# 2480            surf
# 4158             NaN
# 4213             NaN
# 5264         fishing
# 4665          diving
# 1348            surf
# 5012    sea disaster
# 4186        swimming
# 2377            surf
# 900           diving
# 3860        swimming
# 4305         fishing
# 1209          diving
# 537             surf
# Name: Activity, dtype: object

# %% [markdown]
# # COLUMNA INJURY

# %%
list(df['Fatal_(y/n)'].unique())
# Out:
# ['N', 'Y', nan, 'M', '2017', 'UNKNOWN', ' N']

# %%
df[["Fatal_(y/n)","Injury"]].sample(30)
# Out:
#      Fatal_(y/n)                                             Injury
# 4026           N                           No injury, shark bit oar
# 1544           N                                       Thigh bitten
# 4407           N                                        Foot bitten
# 1853           N                             Foot & ankle lacerated
# 1723           N               Right shoulder forarm & wrist bitten
# 3360           N  No injury to occupant, shark lifted canoe's ou...
# 4537           N                                          Lost hand
# 799            N                            No injury, kayak bitten
# 3426           N                                         Arm bitten
# 3701           N                Laceration to arm PROVOKED INCIDENT
# 657            N                                 Minor leg injuries
# 2211           N                         Left hand & forearm bitten
# 5308           N                                     Buttock bitten
# 1893           N                                 Both thighs bitten
# 5050           N                                          Non-Fatal
# 2120           N                                  Wrist & am bitten
# 4939           Y                                              FATAL
# 1780           N  Two half-inch lacerations on right heel and on...
# 3467           N                                       Ankle bitten
# 3726           Y                          FATAL, body not recovered
# 840            N           Lacerations to  lower right leg and foot
# 4746           Y                                              FATAL
# 3322           N                            Punctures on left thigh
# 2197           N                              Leg & chest lacerated
# 1535           N  No injury to occupants, one of the boat's flot...
# 2354           N                     Puncture wounds to right thigh
# 4343           Y  FATAL, taken by shark, body not recovered. Twe...
# 1331           N  Bruises to arm and hand, laceration to lower l...
# 1096           N        No injury to occupants, shark bit propeller
# 2159           N                                  Right foot bitten

# %% [markdown]
# - El tema de valores distintos de los previsibles "Y"/ "N" ademas de categorizar la columna injury lo vamos a hacer a través de dos funciones

# %%
def lesiones (string):
    x = str(string).lower() # para no tener que meter mas cosas en los filtros d elos bucles
    if "fatal" in x and "non" not in x:
        return "fatal"
    elif "no injury" in x or "not injured" in x: #Por la mierda de coincidencias que tenían non y daban
        return "no injury"
    else:
        return "injury"

# %%
df["Injury"] = df["Injury"].apply(lesiones)

# %%
def fatal (string):
    if string in ['N', 'M',' N', 'N ']:
        return "N"
    elif string in ['Y','y']:
        return "Y"
    else:
        return np.nan

# %%
df['Fatal_(y/n)'] = df["Fatal_(y/n)"].apply(fatal)

# %%
df[["Fatal_(y/n)","Injury"]].sample(10)
# Out:
#      Fatal_(y/n)  Injury
# 2944           N  injury
# 551            Y   fatal
# 903            N  injury
# 4759         NaN  injury
# 2601           N  injury
# 4538           Y   fatal
# 197            N  injury
# 981            N  injury
# 4863           Y   fatal
# 3711           N  injury

# %% [markdown]
# # SPECIES COLUMN

# %%
df.Species.sample(30)
# Out:
# 4425                                                 NaN
# 5047                                                 NaN
# 4264                                         Tiger shark
# 3445                                     3 m [10'] shark
# 1295    3' small spotted catshark, Scyliorhinus canicula
# 2483                                                 NaN
# 5052                                                 NaN
# 4421       Thought to involve a mako or grey nurse shark
# 676                                            10' shark
# 4286                                          Bull shark
# 1775                                             Invalid
# 1358                                             Invalid
# 485                                                  NaN
# 4517                                         Tiger shark
# 2678                                           6 m shark
# 2927                                                 NaN
# 2080                                                 NaN
# 1706                            60 cm [2'] captive shark
# 2896                                           15' shark
# 3151                                                 NaN
# 4179                                                 NaN
# 3480                                                 NaN
# 5033                                                 NaN
# 2787                                                 NaN
# 2637                                           2 m shark
# 2657                                    6', 100-lb shark
# 3158                                          Mako shark
# 749                                       4' to 5' shark
# 1177                                                 NaN
# 2716                                                 NaN
# Name: Species, dtype: object

# %% [markdown]
# - Para limpiar esto vamos a usar algo parecido a lo que hemos hecho con activity para categorizar y leer las cadenas de dentro.Usaré la lista de nombres de https://sharkattackfile.net/species.htm
#  que es de donde viene nuestro dataframe además

# %%
def species (string):
    x = str(string).lower()
    if "whitetip" in x or "whtietip" in x:
        return "whitetip reef"
    elif "white" in x:
        return "white"
    elif "bull" in x or "zambesi" in x:
        return "bull"
    elif "tiger" in x:
        return "tiger"
    elif "lemon" in x:
        return "lemon"
    elif "nurse" in x:
        return "nurse"
    elif "caribbean" in x:
        return "caribbean reef"
    elif "blacktip" in x or "blacktail" in x:
        return "blacktip"
    elif "grey" in x or "gray" in x:
        return "grey reef shark"
    elif "wobbegong" in x:
        return "wobbegong"
    elif "blue" in x:
        return "blue"
    elif "spinner" in x:
        return "spinner"
    elif "unconfirmed" in x or "questionable " in x:
        return np.nan
    elif "galapagos" in x:
        return "galapagos"
    elif "porbeagle" in x:
        return "porbeagle"
    elif "hammerhead" in x:
        return "hammerhead"
    elif "mako" in x:
        return "mako"
    elif "goblin" in x:
        return "goblin"
    elif "sandbar" in x or "raggedtooth" in x:
        return "sand tiger"
    elif "angel" in x:
        return "angel"
    elif "silky" in x:
        return "silky"
    elif "whaler" in x:
        return "bronze whaler"
    elif "sevengill " in x:
        return "broadnose sevengill"
    elif "nan" == x:
        return np.nan
    else:
        return np.nan

# %%
df.Species = df.Species.apply(species)

# %%
df.Species.sample(30)
# Out:
# 4892                NaN
# 4518                NaN
# 823                 NaN
# 788                 NaN
# 2301              lemon
# 4812                NaN
# 2617           blacktip
# 4316              white
# 4211          porbeagle
# 3572                NaN
# 2414    grey reef shark
# 275                 NaN
# 1577              white
# 2767                NaN
# 357                 NaN
# 213                bull
# 5120                NaN
# 1508                NaN
# 2471              white
# 2246              tiger
# 1957              tiger
# 538                 NaN
# 2450                NaN
# 4117                NaN
# 3833              white
# 5036                NaN
# 2971      bronze whaler
# 916                mako
# 4038                NaN
# 4490                NaN
# Name: Species, dtype: object

# %% [markdown]
# # Exportamos el data frame limpio a un CSV nuevo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv("/content/drive/MyDrive/dataset/attack_limpio.csv",index=False)
